# %%
import pandas as pd
import numpy as np

# %%
from mp_api.client import MPRester # Importing mp_api library
api_key = "ZbGxsvtmixirV3kWQRUGTzNaLQqdZQHD" #this is my api_key
mpr = MPRester(api_key=api_key) # creating MPRester object

# %%
# Define A-site (alkaline and rare earth metals) and B-site (transition metals)
alkaline_metals = ["Li", "Na", "K", "Rb", "Cs", "Be", "Mg", "Ca", "Sr", "Ba"]
rare_earth_metals = ["La", "Ce", "Pr", "Nd", "Sm", "Eu", "Gd", "Tb", "Dy", "Ho", "Er", "Tm", "Yb", "Lu"]
transition_metals = ["Sc", "Ti", "V", "Cr", "Mn", "Fe", "Co", "Ni", "Cu", "Zn", "Y", "Zr", "Nb", "Mo", "Ru", "Rh", 
                     "Pd", "Ag", "Cd", "Hf", "Ta", "W", "Re", "Os", "Ir", "Pt", "Au"]

# Combine alkaline and rare earth metals for A-site elements
elements_A = alkaline_metals + rare_earth_metals
anions_X = ["O","Cl", "Br", "I", "F", "S", "Se", "Te"]  # Common X-site elements
all_elements = elements_A+anions_X+transition_metals

# %%
# Querying the data (oxides)
data = mpr.materials.summary.search(formula="AABCX6", fields= ['formula_pretty','nsites','chemsys','volume','density','density_atomic',
                                                             'energy_per_atom','formation_energy_per_atom','is_stable',
                                                            'band_gap','cbm','vbm','efermi','is_gap_direct',
                                                            'is_magnetic','ordering','total_magnetization',
                                                             'total_magnetization_normalized_vol','total_magnetization_normalized_formula_units',
                                                            'structure','is_metal','symmetry','energy_above_hull','elements'])
# Out:
# Retrieving SummaryDoc documents:   0%|          | 0/4817 [00:00<?, ?it/s]

# %%
def is_double_perovskite(row):
    elements = [str(el) for el in row['elements']]  # Convert elements to string format

    # A site should contain alkali, alkaline earth, or rare earth metals
    A_elements = [elem for elem in elements if elem in elements_A]
    
    # B and C sites should contain transition metals
    B_C_elements = [elem for elem in elements if elem in transition_metals]
    
    # X site should be in the anions list (oxides or halides)
    X_elements = [elem for elem in elements if elem in anions_X]
    
    # Check if the structure matches A2BCX6: 2 A elements, 2 B/C elements, 1 X element
    return len(A_elements) >= 1 and len(B_C_elements) >= 2 and len(X_elements) == 1

# %%
df = pd.DataFrame([doc.dict() for doc in data])

# %%
df['is_double_perovskite'] = df.apply(is_double_perovskite, axis=1)

# %%
df_double_perovskites = df[df['is_double_perovskite']]

# %%
df_double_perovskites[['formula_pretty','chemsys','elements']]
# Out:
#      formula_pretty     chemsys         elements
# 43        Ba2CdMoO6  Ba-Cd-Mo-O  [Ba, Cd, Mo, O]
# 44        Ba2CdOsO6  Ba-Cd-O-Os  [Ba, Cd, O, Os]
# 45        Ba2CdReO6  Ba-Cd-O-Re  [Ba, Cd, O, Re]
# 71        Ba2CoMoO6  Ba-Co-Mo-O  [Ba, Co, Mo, O]
# 72        Ba2CoMoO6  Ba-Co-Mo-O  [Ba, Co, Mo, O]
# ...             ...         ...              ...
# 4806       Rb2YAuI6   Au-I-Rb-Y   [Au, I, Rb, Y]
# 4807      Rb2YCuBr6  Br-Cu-Rb-Y  [Br, Cu, Rb, Y]
# 4808      Rb2YCuCl6  Cl-Cu-Rb-Y  [Cl, Cu, Rb, Y]
# 4809       Rb2YCuF6   Cu-F-Rb-Y   [Cu, F, Rb, Y]
# 4810       Rb2YCuI6   Cu-I-Rb-Y   [Cu, I, Rb, Y]
#
# [920 rows x 3 columns]

# %%
df_double_perovskites.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 43 to 4810
# Data columns (total 71 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   builder_meta                                  0 non-null      object
#  1   nsites                                        920 non-null    int64
#  2   elements                                      920 non-null    object
#  3   nelements                                     0 non-null      object
#  4   composition                                   0 non-null      object
#  5   composition_reduced                           0 non-null      object
#  6   formula_pretty                                920 non-null    object
#  7   formula_anonymous                             0 non-null      object
#  8   chemsys                                       920 non-null    object
#  9   volume                                        920 non-null    float64
#  10  density                                       920 non-null    float64
#  11  density_atomic                                920 non-null    float64
#  12  symmetry                                      920 non-null    object
#  13  property_name                                 0 non-null      object
#  14  material_id                                   0 non-null      object
#  15  deprecated                                    0 non-null      object
#  16  deprecation_reasons                           0 non-null      object
#  17  last_updated                                  0 non-null      object
#  18  origins                                       0 non-null      object
#  19  warnings                                      0 non-null      object
#  20  structure                                     920 non-null    object
#  21  task_ids                                      0 non-null      object
#  22  uncorrected_energy_per_atom                   0 non-null      object
#  23  energy_per_atom                               920 non-null    float64
#  24  formation_energy_per_atom                     920 non-null    float64
#  25  energy_above_hull                             920 non-null    float64
#  26  is_stable                                     920 non-null    bool
#  27  equilibrium_reaction_energy_per_atom          0 non-null      object
#  28  decomposes_to                                 0 non-null      object
#  29  xas                                           0 non-null      object
#  30  grain_boundaries                              0 non-null      object
#  31  band_gap                                      920 non-null    float64
#  32  cbm                                           594 non-null    float64
#  33  vbm                                           594 non-null    float64
#  34  efermi                                        920 non-null    float64
#  35  is_gap_direct                                 920 non-null    bool
#  36  is_metal                                      920 non-null    bool
#  37  es_source_calc_id                             0 non-null      object
#  38  bandstructure                                 0 non-null      object
#  39  dos                                           0 non-null      object
#  40  dos_energy_up                                 0 non-null      object
#  41  dos_energy_down                               0 non-null      object
#  42  is_magnetic                                   892 non-null    object
#  43  ordering                                      892 non-null    object
#  44  total_magnetization                           892 non-null    float64
#  45  total_magnetization_normalized_vol            892 non-null    float64
#  46  total_magnetization_normalized_formula_units  892 non-null    float64
#  47  num_magnetic_sites                            0 non-null      object
#  48  num_unique_magnetic_sites                     0 non-null      object
#  49  types_of_magnetic_species                     0 non-null      object
#  50  bulk_modulus                                  0 non-null      object
#  51  shear_modulus                                 0 non-null      object
#  52  universal_anisotropy                          0 non-null      object
#  53  homogeneous_poisson                           0 non-null      object
#  54  e_total                                       0 non-null      object
#  55  e_ionic                                       0 non-null      object
#  56  e_electronic                                  0 non-null      object
#  57  n                                             0 non-null      object
#  58  e_ij_max                                      0 non-null      object
#  59  weighted_surface_energy_EV_PER_ANG2           0 non-null      object
#  60  weighted_surface_energy                       0 non-null      object
#  61  weighted_work_function                        0 non-null      object
#  62  surface_anisotropy                            0 non-null      object
#  63  shape_factor                                  0 non-null      object
#  64  has_reconstructed                             0 non-null      object
#  65  possible_species                              0 non-null      object
#  66  has_props                                     0 non-null      object
#  67  theoretical                                   0 non-null      object
#  68  database_IDs                                  0 non-null      object
#  69  fields_not_requested                          920 non-null    object
#  70  is_double_perovskite                          920 non-null    bool
# dtypes: bool(4), float64(13), int64(1), object(53)
# memory usage: 492.3+ KB

# %%
columns_of_interest = ['nsites','chemsys','volume','density','density_atomic',
                       'energy_per_atom','formation_energy_per_atom','is_stable',
                        'band_gap','cbm','vbm','efermi','is_gap_direct','is_metal',
                        'is_magnetic','ordering','total_magnetization',
                        'total_magnetization_normalized_vol','total_magnetization_normalized_formula_units',
                      'symmetry','structure','energy_above_hull']

# %%
refined_perovskite_df = df_double_perovskites[columns_of_interest]

# %%
refined_perovskite_df
# Out:
#       nsites     chemsys      volume   density  density_atomic  \
# 43        10  Ba-Cd-Mo-O  152.172247  6.318198       15.217225
# 44        10  Ba-Cd-O-Os  150.605592  7.423540       15.060559
# 45        10  Ba-Cd-O-Re  151.219499  7.349226       15.121950
# 71        20  Ba-Co-Mo-O  276.766068  6.306065       13.838303
# 72        20  Ba-Co-Mo-O  277.167172  6.296940       13.858359
# ...      ...         ...         ...       ...             ...
# 4806      10   Au-I-Rb-Y  443.643517  4.559802       44.364352
# 4807      10  Br-Cu-Rb-Y  332.890138  4.004624       33.289014
# 4808      10  Cl-Cu-Rb-Y  283.652711  3.138430       28.365271
# 4809      10   Cu-F-Rb-Y  179.308176  4.050474       17.930818
# 4810      10   Cu-I-Rb-Y  414.928559  4.341414       41.492856
#
#       energy_per_atom  formation_energy_per_atom  is_stable  band_gap     cbm  \
# 43          -7.002457                  -2.466738       True    2.5376  4.6264
# 44          -6.794457                  -2.220566       True    0.0000     NaN
# 45          -7.155684                  -2.459718      False    0.0000     NaN
# 71          -7.613764                  -2.460704       True    0.0000     NaN
# 72          -7.604548                  -2.451488      False    1.2740  4.2504
# ...               ...                        ...        ...       ...     ...
# 4806        -3.403616                  -1.345192      False    1.1678  2.4738
# 4807        -4.048370                  -1.859617      False    2.3405  3.4050
# 4808        -4.496769                  -2.130710      False    2.6201  4.4170
# 4809        -5.549890                  -3.146066      False    0.9338  3.3825
# 4810        -3.520014                  -1.379058      False    1.8014  3.6691
#
#       ...  is_gap_direct  is_metal  is_magnetic  ordering total_magnetization  \
# 43    ...          False     False        False        NM            0.000024
# 44    ...          False      True         True        FM            1.999998
# 45    ...          False      True         True        FM            1.000072
# 71    ...          False      True         True       AFM            0.010982
# 72    ...           True     False         True       AFM            0.000002
# ...   ...            ...       ...          ...       ...                 ...
# 4806  ...          False     False        False        NM            0.001489
# 4807  ...          False     False        False        NM            0.000269
# 4808  ...          False     False        False        NM            0.000190
# 4809  ...          False     False        False        NM            0.000227
# 4810  ...          False     False        False        NM            0.000268
#
#      total_magnetization_normalized_vol  \
# 43                         1.550874e-07
# 44                         1.327971e-02
# 45                         6.613381e-03
# 71                         3.968008e-05
# 72                         7.576655e-09
# ...                                 ...
# 4806                       3.355848e-06
# 4807                       8.068728e-07
# 4808                       6.698332e-07
# 4809                       1.267092e-06
# 4810                       6.456533e-07
#
#       total_magnetization_normalized_formula_units  \
# 43                                        0.000024
# 44                                        1.999998
# 45                                        1.000072
# 71                                        0.005491
# 72                                        0.000001
# ...                                            ...
# 4806                                      0.001489
# 4807                                      0.000269
# 4808                                      0.000190
# 4809                                      0.000227
# 4810                                      0.000268
#
#                                                symmetry  \
# 43    {'crystal_system': 'Cubic', 'symbol': 'Fm-3m',...
# 44    {'crystal_system': 'Cubic', 'symbol': 'Fm-3m',...
# 45    {'crystal_system': 'Cubic', 'symbol': 'Fm-3m',...
# 71    {'crystal_system': 'Cubic', 'symbol': 'Fm-3m',...
# 72    {'crystal_system': 'Tetragonal', 'symbol': 'I4...
# ...                                                 ...
# 4806  {'crystal_system': 'Cubic', 'symbol': 'Fm-3m',...
# 4807  {'crystal_system': 'Cubic', 'symbol': 'Fm-3m',...
# 4808  {'crystal_system': 'Cubic', 'symbol': 'Fm-3m',...
# 4809  {'crystal_system': 'Cubic', 'symbol': 'Fm-3m',...
# 4810  {'crystal_system': 'Cubic', 'symbol': 'Fm-3m',...
#
#                                               structure energy_above_hull
# 43    {'@module': 'pymatgen.core.structure', '@class...          0.000000
# 44    {'@module': 'pymatgen.core.structure', '@class...          0.000000
# 45    {'@module': 'pymatgen.core.structure', '@class...          0.000618
# 71    {'@module': 'pymatgen.core.structure', '@class...          0.000000
# 72    {'@module': 'pymatgen.core.structure', '@class...          0.009216
# ...                                                 ...               ...
# 4806  {'@module': 'pymatgen.core.structure', '@class...          0.105849
# 4807  {'@module': 'pymatgen.core.structure', '@class...          0.035860
# 4808  {'@module': 'pymatgen.core.structure', '@class...          0.042300
# 4809  {'@module': 'pymatgen.core.structure', '@class...          0.084484
# 4810  {'@module': 'pymatgen.core.structure', '@class...          0.082740
#
# [920 rows x 22 columns]

# %%
refined_perovskite_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 43 to 4810
# Data columns (total 22 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   nsites                                        920 non-null    int64
#  1   chemsys                                       920 non-null    object
#  2   volume                                        920 non-null    float64
#  3   density                                       920 non-null    float64
#  4   density_atomic                                920 non-null    float64
#  5   energy_per_atom                               920 non-null    float64
#  6   formation_energy_per_atom                     920 non-null    float64
#  7   is_stable                                     920 non-null    bool
#  8   band_gap                                      920 non-null    float64
#  9   cbm                                           594 non-null    float64
#  10  vbm                                           594 non-null    float64
#  11  efermi                                        920 non-null    float64
#  12  is_gap_direct                                 920 non-null    bool
#  13  is_metal                                      920 non-null    bool
#  14  is_magnetic                                   892 non-null    object
#  15  ordering                                      892 non-null    object
#  16  total_magnetization                           892 non-null    float64
#  17  total_magnetization_normalized_vol            892 non-null    float64
#  18  total_magnetization_normalized_formula_units  892 non-null    float64
#  19  symmetry                                      920 non-null    object
#  20  structure                                     920 non-null    object
#  21  energy_above_hull                             920 non-null    float64
# dtypes: bool(3), float64(13), int64(1), object(5)
# memory usage: 146.4+ KB

# %%
# Now, as we see above, the structure and symmetry columns don't look good
# We need to extract the information useful for us from those columns and make separate columns

# Extracting crystal_system
refined_perovskite_df['crystal_system'] = refined_perovskite_df['symmetry'].apply(lambda x: x['crystal_system'])

# Extracting abc and angles
def extract_abc_angles(structure):
    abc = structure['lattice']['a'], structure['lattice']['b'], structure['lattice']['c']
    angles = structure['lattice']['alpha'], structure['lattice']['beta'], structure['lattice']['gamma']
    return pd.Series({'a': abc[0], 'b': abc[1], 'c': abc[2], 'alpha': angles[0], 'beta': angles[1], 'gamma': angles[2]})

refined_perovskite_df[['a', 'b', 'c', 'alpha', 'beta', 'gamma']] = refined_perovskite_df['structure'].apply(extract_abc_angles)
# Out:
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2668737861.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df['crystal_system'] = refined_perovskite_df['symmetry'].apply(lambda x: x['crystal_system'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2668737861.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['a', 'b', 'c', 'alpha', 'beta', 'gamma']] = refined_perovskite_df['structure'].apply(extract_abc_angles)
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2668737861.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['a', 'b', 'c', 'alpha', 'beta', 'gamma']] = refined_perovskite_df['structure'].apply(extract_abc_angles)
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2668737861.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['a', 'b', 'c', 'alpha', 'beta', 'gamma']] = refined_perovskite_df['structure'].apply(extract_abc_angles)
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2668737861.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['a', 'b', 'c', 'alpha', 'beta', 'gamma']] = refined_perovskite_df['structure'].apply(extract_abc_angles)
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2668737861.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['a', 'b', 'c', 'alpha', 'beta', 'gamma']] = refined_perovskite_df['structure'].apply(extract_abc_angles)
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2668737861.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['a', 'b', 'c', 'alpha', 'beta', 'gamma']] = refined_perovskite_df['structure'].apply(extract_abc_angles)

# %%
refined_perovskite_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 43 to 4810
# Data columns (total 29 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   nsites                                        920 non-null    int64
#  1   chemsys                                       920 non-null    object
#  2   volume                                        920 non-null    float64
#  3   density                                       920 non-null    float64
#  4   density_atomic                                920 non-null    float64
#  5   energy_per_atom                               920 non-null    float64
#  6   formation_energy_per_atom                     920 non-null    float64
#  7   is_stable                                     920 non-null    bool
#  8   band_gap                                      920 non-null    float64
#  9   cbm                                           594 non-null    float64
#  10  vbm                                           594 non-null    float64
#  11  efermi                                        920 non-null    float64
#  12  is_gap_direct                                 920 non-null    bool
#  13  is_metal                                      920 non-null    bool
#  14  is_magnetic                                   892 non-null    object
#  15  ordering                                      892 non-null    object
#  16  total_magnetization                           892 non-null    float64
#  17  total_magnetization_normalized_vol            892 non-null    float64
#  18  total_magnetization_normalized_formula_units  892 non-null    float64
#  19  symmetry                                      920 non-null    object
#  20  structure                                     920 non-null    object
#  21  energy_above_hull                             920 non-null    float64
#  22  crystal_system                                920 non-null    object
#  23  a                                             920 non-null    float64
#  24  b                                             920 non-null    float64
#  25  c                                             920 non-null    float64
#  26  alpha                                         920 non-null    float64
#  27  beta                                          920 non-null    float64
#  28  gamma                                         920 non-null    float64
# dtypes: bool(3), float64(19), int64(1), object(6)
# memory usage: 196.8+ KB

# %%
# We can observe that we have successfully extracted the crystal_system, abc and angles
# Now we have to extract data from the chemsys column. We need to separate the elements and store in separate columns

# Extracting chemsys data
# Split the chemsys column into separate elements
split_chemsys = refined_perovskite_df['chemsys'].str.split('-', expand=True)

# Assign new columns for each element
refined_perovskite_df['element_1'] = split_chemsys[0]
refined_perovskite_df['element_2'] = split_chemsys[1]
refined_perovskite_df['element_3'] = split_chemsys[2]
refined_perovskite_df['element_4'] = split_chemsys[3]
# Out:
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\1559298818.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df['element_1'] = split_chemsys[0]
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\1559298818.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df['element_2'] = split_chemsys[1]
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\1559298818.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df['element_3'] = split_chemsys[2]
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\1559298818.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df['element_4'] = split_chemsys[3]

# %%
refined_perovskite_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 43 to 4810
# Data columns (total 33 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   nsites                                        920 non-null    int64
#  1   chemsys                                       920 non-null    object
#  2   volume                                        920 non-null    float64
#  3   density                                       920 non-null    float64
#  4   density_atomic                                920 non-null    float64
#  5   energy_per_atom                               920 non-null    float64
#  6   formation_energy_per_atom                     920 non-null    float64
#  7   is_stable                                     920 non-null    bool
#  8   band_gap                                      920 non-null    float64
#  9   cbm                                           594 non-null    float64
#  10  vbm                                           594 non-null    float64
#  11  efermi                                        920 non-null    float64
#  12  is_gap_direct                                 920 non-null    bool
#  13  is_metal                                      920 non-null    bool
#  14  is_magnetic                                   892 non-null    object
#  15  ordering                                      892 non-null    object
#  16  total_magnetization                           892 non-null    float64
#  17  total_magnetization_normalized_vol            892 non-null    float64
#  18  total_magnetization_normalized_formula_units  892 non-null    float64
#  19  symmetry                                      920 non-null    object
#  20  structure                                     920 non-null    object
#  21  energy_above_hull                             920 non-null    float64
#  22  crystal_system                                920 non-null    object
#  23  a                                             920 non-null    float64
#  24  b                                             920 non-null    float64
#  25  c                                             920 non-null    float64
#  26  alpha                                         920 non-null    float64
#  27  beta                                          920 non-null    float64
#  28  gamma                                         920 non-null    float64
#  29  element_1                                     920 non-null    object
#  30  element_2                                     920 non-null    object
#  31  element_3                                     920 non-null    object
#  32  element_4                                     920 non-null    object
# dtypes: bool(3), float64(19), int64(1), object(10)
# memory usage: 225.5+ KB

# %%
# From the above output, we have successfully extracted the elements in the perovskite
# But, ML models need numbers to work with
# We can encode the elements coulmns with their respective atomic numbers

# Predefined dictionary for atomic numbers
atomic_numbers = {
    'H': 1, 'He': 2, 'Li': 3, 'Be': 4, 'B': 5, 'C': 6, 'N': 7, 'O': 8, 'F': 9, 'Ne': 10,
    'Na': 11, 'Mg': 12, 'Al': 13, 'Si': 14, 'P': 15, 'S': 16, 'Cl': 17, 'Ar': 18, 'K': 19, 'Ca': 20,
    'Sc': 21, 'Ti': 22, 'V': 23, 'Cr': 24, 'Mn': 25, 'Fe': 26, 'Co': 27, 'Ni': 28, 'Cu': 29, 'Zn': 30,
    'Ga': 31, 'Ge': 32, 'As': 33, 'Se': 34, 'Br': 35, 'Kr': 36, 'Rb': 37, 'Sr': 38, 'Y': 39, 'Zr': 40,
    'Nb': 41, 'Mo': 42, 'Tc': 43, 'Ru': 44, 'Rh': 45, 'Pd': 46, 'Ag': 47, 'Cd': 48, 'In': 49, 'Sn': 50,
    'Sb': 51, 'Te': 52, 'I': 53, 'Xe': 54, 'Cs': 55, 'Ba': 56, 'La': 57, 'Ce': 58, 'Pr': 59, 'Nd': 60,
    'Pm': 61, 'Sm': 62, 'Eu': 63, 'Gd': 64, 'Tb': 65, 'Dy': 66, 'Ho': 67, 'Er': 68, 'Tm': 69, 'Yb': 70,
    'Lu': 71, 'Hf': 72, 'Ta': 73, 'W': 74, 'Re': 75, 'Os': 76, 'Ir': 77, 'Pt': 78, 'Au': 79, 'Hg': 80,
    'Tl': 81, 'Pb': 82, 'Bi': 83, 'Po': 84, 'At': 85, 'Rn': 86, 'Fr': 87, 'Ra': 88, 'Ac': 89, 'Th': 90,
    'Pa': 91, 'U': 92, 'Np': 93, 'Pu': 94, 'Am': 95, 'Cm': 96, 'Bk': 97, 'Cf': 98, 'Es': 99, 'Fm': 100,
    'Md': 101, 'No': 102, 'Lr': 103, 'Rf': 104, 'Db': 105, 'Sg': 106, 'Bh': 107, 'Hs': 108, 'Mt': 109,
    'Ds': 110, 'Rg': 111, 'Cn': 112, 'Nh': 113, 'Fl': 114, 'Mc': 115, 'Lv': 116, 'Ts': 117, 'Og': 118
}

# Function to extract elements and atomic numbers
def extract_elements_atomic_numbers(row):
    elements = row['chemsys'].split('-')
    atomic_nums = [atomic_numbers[element] for element in elements]
    return pd.Series(atomic_nums)

refined_perovskite_df[['atomic_num1', 'atomic_num2', 'atomic_num3','atomic_num4']] = refined_perovskite_df.apply(extract_elements_atomic_numbers, axis=1)
# Out:
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2977053822.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['atomic_num1', 'atomic_num2', 'atomic_num3','atomic_num4']] = refined_perovskite_df.apply(extract_elements_atomic_numbers, axis=1)
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2977053822.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['atomic_num1', 'atomic_num2', 'atomic_num3','atomic_num4']] = refined_perovskite_df.apply(extract_elements_atomic_numbers, axis=1)
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2977053822.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['atomic_num1', 'atomic_num2', 'atomic_num3','atomic_num4']] = refined_perovskite_df.apply(extract_elements_atomic_numbers, axis=1)
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\2977053822.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   refined_perovskite_df[['atomic_num1', 'atomic_num2', 'atomic_num3','atomic_num4']] = refined_perovskite_df.apply(extract_elements_atomic_numbers, axis=1)

# %%
refined_perovskite_df
# Out:
#       nsites     chemsys      volume   density  density_atomic  \
# 43        10  Ba-Cd-Mo-O  152.172247  6.318198       15.217225
# 44        10  Ba-Cd-O-Os  150.605592  7.423540       15.060559
# 45        10  Ba-Cd-O-Re  151.219499  7.349226       15.121950
# 71        20  Ba-Co-Mo-O  276.766068  6.306065       13.838303
# 72        20  Ba-Co-Mo-O  277.167172  6.296940       13.858359
# ...      ...         ...         ...       ...             ...
# 4806      10   Au-I-Rb-Y  443.643517  4.559802       44.364352
# 4807      10  Br-Cu-Rb-Y  332.890138  4.004624       33.289014
# 4808      10  Cl-Cu-Rb-Y  283.652711  3.138430       28.365271
# 4809      10   Cu-F-Rb-Y  179.308176  4.050474       17.930818
# 4810      10   Cu-I-Rb-Y  414.928559  4.341414       41.492856
#
#       energy_per_atom  formation_energy_per_atom  is_stable  band_gap     cbm  \
# 43          -7.002457                  -2.466738       True    2.5376  4.6264
# 44          -6.794457                  -2.220566       True    0.0000     NaN
# 45          -7.155684                  -2.459718      False    0.0000     NaN
# 71          -7.613764                  -2.460704       True    0.0000     NaN
# 72          -7.604548                  -2.451488      False    1.2740  4.2504
# ...               ...                        ...        ...       ...     ...
# 4806        -3.403616                  -1.345192      False    1.1678  2.4738
# 4807        -4.048370                  -1.859617      False    2.3405  3.4050
# 4808        -4.496769                  -2.130710      False    2.6201  4.4170
# 4809        -5.549890                  -3.146066      False    0.9338  3.3825
# 4810        -3.520014                  -1.379058      False    1.8014  3.6691
#
#       ...        beta       gamma  element_1  element_2 element_3 element_4  \
# 43    ...   60.000000   60.000000         Ba         Cd        Mo         O
# 44    ...   60.000000   60.000000         Ba         Cd         O        Os
# 45    ...   60.000000   60.000000         Ba         Cd         O        Re
# 71    ...   90.021108  119.962715         Ba         Co        Mo         O
# 72    ...  119.353138   73.335321         Ba         Co        Mo         O
# ...   ...         ...         ...        ...        ...       ...       ...
# 4806  ...   60.000000   60.000000         Au          I        Rb         Y
# 4807  ...   60.000000   60.000000         Br         Cu        Rb         Y
# 4808  ...   60.000000   60.000000         Cl         Cu        Rb         Y
# 4809  ...   60.000000   60.000000         Cu          F        Rb         Y
# 4810  ...   60.000000   60.000000         Cu          I        Rb         Y
#
#       atomic_num1  atomic_num2  atomic_num3 atomic_num4
# 43             56           48           42           8
# 44             56           48            8          76
# 45             56           48            8          75
# 71             56           27           42           8
# 72             56           27           42           8
# ...           ...          ...          ...         ...
# 4806           79           53           37          39
# 4807           35           29           37          39
# 4808           17           29           37          39
# 4809           29            9           37          39
# 4810           29           53           37          39
#
# [920 rows x 37 columns]

# %%
# We have successfully extracted the atomic numbers also
# Now we can drop the symmetry and structure columns as we have the data

refined_perovskite_df = refined_perovskite_df.drop(columns=['symmetry','structure'])

# %%
refined_perovskite_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 43 to 4810
# Data columns (total 35 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   nsites                                        920 non-null    int64
#  1   chemsys                                       920 non-null    object
#  2   volume                                        920 non-null    float64
#  3   density                                       920 non-null    float64
#  4   density_atomic                                920 non-null    float64
#  5   energy_per_atom                               920 non-null    float64
#  6   formation_energy_per_atom                     920 non-null    float64
#  7   is_stable                                     920 non-null    bool
#  8   band_gap                                      920 non-null    float64
#  9   cbm                                           594 non-null    float64
#  10  vbm                                           594 non-null    float64
#  11  efermi                                        920 non-null    float64
#  12  is_gap_direct                                 920 non-null    bool
#  13  is_metal                                      920 non-null    bool
#  14  is_magnetic                                   892 non-null    object
#  15  ordering                                      892 non-null    object
#  16  total_magnetization                           892 non-null    float64
#  17  total_magnetization_normalized_vol            892 non-null    float64
#  18  total_magnetization_normalized_formula_units  892 non-null    float64
#  19  energy_above_hull                             920 non-null    float64
#  20  crystal_system                                920 non-null    object
#  21  a                                             920 non-null    float64
#  22  b                                             920 non-null    float64
#  23  c                                             920 non-null    float64
#  24  alpha                                         920 non-null    float64
#  25  beta                                          920 non-null    float64
#  26  gamma                                         920 non-null    float64
#  27  element_1                                     920 non-null    object
#  28  element_2                                     920 non-null    object
#  29  element_3                                     920 non-null    object
#  30  element_4                                     920 non-null    object
#  31  atomic_num1                                   920 non-null    int64
#  32  atomic_num2                                   920 non-null    int64
#  33  atomic_num3                                   920 non-null    int64
#  34  atomic_num4                                   920 non-null    int64
# dtypes: bool(3), float64(19), int64(5), object(8)
# memory usage: 239.9+ KB

# %%
from mendeleev import element

# Step 1: Extract unique elements from your DataFrame
unique_elements = pd.concat([refined_perovskite_df['element_1'], 
                             refined_perovskite_df['element_2'], 
                             refined_perovskite_df['element_3'],
                             refined_perovskite_df['element_4']]).unique()

# Step 2: Fetch properties for each unique element
element_properties = {}

# %%
## The below properties are extracted from pymatgen ##

from pymatgen.core import Element

# List of properties to extract
properties = ['group', 'row', 'electronegativity', 'atomic_radius', 'atomic_radius_calculated', 
              'van_der_waals_radius', 'mendeleev_no', 'molar_volume', 
              'electron_affinity', 'ionization_energy', 'average_ionic_radius', 
              'coefficient_of_linear_thermal_expansion', 'density_of_solid', 
              'boiling_point', 'melting_point', 'thermal_conductivity']

for elem in unique_elements:
    try:
        element = Element(elem)
        element_properties[elem] = {
            'group': element.group,
            'row': element.row,
            'electronegativity': element.X,
            'atomic_radius': element.atomic_radius,
            'atomic_radius_calculated': element.atomic_radius_calculated,
            'van_der_waals_radius': element.van_der_waals_radius,
            'mendeleev_no': element.mendeleev_no,
            'molar_volume': element.molar_volume,
            'electron_affinity': element.electron_affinity,
            'ionization_energy': element.ionization_energies[0] if element.ionization_energies else np.nan,
            'average_ionic_radius': element.average_ionic_radius,
            'coefficient_of_linear_thermal_expansion': element.coefficient_of_linear_thermal_expansion,
            'density_of_solid': element.density_of_solid,
            'boiling_point': element.boiling_point,
            'melting_point': element.melting_point,
            'thermal_conductivity': element.thermal_conductivity
        }
    except Exception as e:
        # If data is missing, fill with NaN
        element_properties[elem] = {prop: np.nan for prop in properties}
        print(f"Data not available for element {elem}: {e}")

# Now mapping the properties to the DataFrame
for i in range(1, 5):  # element_1, element_2, element_3, element_4
    for prop in properties:
        refined_perovskite_df[f'element_{i}_{prop}'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x][prop])

# After this, the periodic table properties for each element will be added to the dataframe.
# Out:
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for atomic_radius_calculated for Ce
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for coefficient_of_linear_thermal_expansion for Br
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for density_of_solid for Br
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for coefficient_of_linear_thermal_expansion for Cl
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for density_of_solid for Cl
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for coefficient_of_linear_thermal_expansion for Cs
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for atomic_radius_calculated for Ho
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for coefficient_of_linear_thermal_expansion for K
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for atomic_radius_calculated for La
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for coefficient_of_linear_thermal_expansion for O
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for density_of_solid for O
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for coefficient_of_linear_thermal_expansion for S
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for coefficient_of_linear_thermal_expansion for F
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for density_of_solid for F
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for coefficient_of_linear_thermal_expansion for I
#   warnings.warn(f"No data available for {item} for {self.symbol}")
# C:\Users\varap\anaconda3\lib\site-packages\pymatgen\core\periodic_table.py:181: UserWarning: No data available for coefficient_of_linear_thermal_expansion for Rb
#   warnings.warn(f"No data available for {item} for {self.symbol}")

# %%
refined_perovskite_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 920 entries, 43 to 4810
# Data columns (total 99 columns):
#  #   Column                                             Non-Null Count  Dtype
# ---  ------                                             --------------  -----
#  0   nsites                                             920 non-null    int64
#  1   chemsys                                            920 non-null    object
#  2   volume                                             920 non-null    float64
#  3   density                                            920 non-null    float64
#  4   density_atomic                                     920 non-null    float64
#  5   energy_per_atom                                    920 non-null    float64
#  6   formation_energy_per_atom                          920 non-null    float64
#  7   is_stable                                          920 non-null    bool
#  8   band_gap                                           920 non-null    float64
#  9   cbm                                                594 non-null    float64
#  10  vbm                                                594 non-null    float64
#  11  efermi                                             920 non-null    float64
#  12  is_gap_direct                                      920 non-null    bool
#  13  is_metal                                           920 non-null    bool
#  14  is_magnetic                                        892 non-null    object
#  15  ordering                                           892 non-null    object
#  16  total_magnetization                                892 non-null    float64
#  17  total_magnetization_normalized_vol                 892 non-null    float64
#  18  total_magnetization_normalized_formula_units       892 non-null    float64
#  19  energy_above_hull                                  920 non-null    float64
#  20  crystal_system                                     920 non-null    object
#  21  a                                                  920 non-null    float64
#  22  b                                                  920 non-null    float64
#  23  c                                                  920 non-null    float64
#  24  alpha                                              920 non-null    float64
#  25  beta                                               920 non-null    float64
#  26  gamma                                              920 non-null    float64
#  27  element_1                                          920 non-null    object
#  28  element_2                                          920 non-null    object
#  29  element_3                                          920 non-null    object
#  30  element_4                                          920 non-null    object
#  31  atomic_num1                                        920 non-null    int64
#  32  atomic_num2                                        920 non-null    int64
#  33  atomic_num3                                        920 non-null    int64
#  34  atomic_num4                                        920 non-null    int64
#  35  element_1_group                                    920 non-null    int64
#  36  element_1_row                                      920 non-null    int64
#  37  element_1_electronegativity                        920 non-null    float64
#  38  element_1_atomic_radius                            920 non-null    float64
#  39  element_1_atomic_radius_calculated                 885 non-null    float64
#  40  element_1_van_der_waals_radius                     920 non-null    float64
#  41  element_1_mendeleev_no                             920 non-null    float64
#  42  element_1_molar_volume                             920 non-null    float64
#  43  element_1_electron_affinity                        920 non-null    float64
#  44  element_1_ionization_energy                        920 non-null    float64
#  45  element_1_average_ionic_radius                     920 non-null    float64
#  46  element_1_coefficient_of_linear_thermal_expansion  853 non-null    float64
#  47  element_1_density_of_solid                         863 non-null    float64
#  48  element_1_boiling_point                            920 non-null    float64
#  49  element_1_melting_point                            920 non-null    float64
#  50  element_1_thermal_conductivity                     920 non-null    float64
#  51  element_2_group                                    920 non-null    int64
#  52  element_2_row                                      920 non-null    int64
#  53  element_2_electronegativity                        920 non-null    float64
#  54  element_2_atomic_radius                            920 non-null    float64
#  55  element_2_atomic_radius_calculated                 879 non-null    float64
#  56  element_2_van_der_waals_radius                     920 non-null    float64
#  57  element_2_mendeleev_no                             920 non-null    float64
#  58  element_2_molar_volume                             920 non-null    float64
#  59  element_2_electron_affinity                        920 non-null    float64
#  60  element_2_ionization_energy                        920 non-null    float64
#  61  element_2_average_ionic_radius                     920 non-null    float64
#  62  element_2_coefficient_of_linear_thermal_expansion  532 non-null    float64
#  63  element_2_density_of_solid                         578 non-null    float64
#  64  element_2_boiling_point                            920 non-null    float64
#  65  element_2_melting_point                            920 non-null    float64
#  66  element_2_thermal_conductivity                     920 non-null    float64
#  67  element_3_group                                    920 non-null    int64
#  68  element_3_row                                      920 non-null    int64
#  69  element_3_electronegativity                        920 non-null    float64
#  70  element_3_atomic_radius                            920 non-null    float64
#  71  element_3_atomic_radius_calculated                 916 non-null    float64
#  72  element_3_van_der_waals_radius                     920 non-null    float64
#  73  element_3_mendeleev_no                             920 non-null    float64
#  74  element_3_molar_volume                             920 non-null    float64
#  75  element_3_electron_affinity                        920 non-null    float64
#  76  element_3_ionization_energy                        920 non-null    float64
#  77  element_3_average_ionic_radius                     920 non-null    float64
#  78  element_3_coefficient_of_linear_thermal_expansion  432 non-null    float64
#  79  element_3_density_of_solid                         553 non-null    float64
#  80  element_3_boiling_point                            920 non-null    float64
#  81  element_3_melting_point                            920 non-null    float64
#  82  element_3_thermal_conductivity                     920 non-null    float64
#  83  element_4_group                                    920 non-null    int64
#  84  element_4_row                                      920 non-null    int64
#  85  element_4_electronegativity                        920 non-null    float64
#  86  element_4_atomic_radius                            920 non-null    float64
#  87  element_4_atomic_radius_calculated                 920 non-null    float64
#  88  element_4_van_der_waals_radius                     920 non-null    float64
#  89  element_4_mendeleev_no                             920 non-null    float64
#  90  element_4_molar_volume                             920 non-null    float64
#  91  element_4_electron_affinity                        920 non-null    float64
#  92  element_4_ionization_energy                        920 non-null    float64
#  93  element_4_average_ionic_radius                     920 non-null    float64
#  94  element_4_coefficient_of_linear_thermal_expansion  748 non-null    float64
#  95  element_4_density_of_solid                         799 non-null    float64
#  96  element_4_boiling_point                            920 non-null    float64
#  97  element_4_melting_point                            920 non-null    float64
#  98  element_4_thermal_conductivity                     920 non-null    float64
# dtypes: bool(3), float64(75), int64(13), object(8)
# memory usage: 699.9+ KB

# %%
from mendeleev import element
for elem in unique_elements:
    try:
        el = element(elem)
        element_properties[elem] = {
            'covalent_radius': el.covalent_radius,
            'fusion_heat': el.fusion_heat,  # Heat of fusion
            'atomic_mass': el.atomic_weight,
            'specific_heat': el.specific_heat,  # Specific heat
            'evaporation_heat': el.evaporation_heat,  # Heat of vaporization
            'dipole_polarizability': el.dipole_polarizability,  # Dipole polarizability
            'density': el.density
        }
    except Exception as e:
        element_properties[elem] = {key: None for key in [
            'covalent_radius', 'fusion_heat', 'atomic_mass', 'specific_heat', 
            'evaporation_heat', 'dipole_polarizability', 'density'
        ]}
        print(f"Data not available for element {elem}: {e}")

# Step 3: Map properties back to the DataFrame
for i in range(1, 5):  # element_1, element_2, element_3 columns
    refined_perovskite_df[f'element_{i}_covalent_radius'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['covalent_radius'])
    refined_perovskite_df[f'element_{i}_fusion_heat'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['fusion_heat'])
    refined_perovskite_df[f'element_{i}_atomic_mass'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['atomic_mass'])
    refined_perovskite_df[f'element_{i}_specific_heat'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['specific_heat'])
    refined_perovskite_df[f'element_{i}_evaporation_heat'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['evaporation_heat'])
    refined_perovskite_df[f'element_{i}_dipole_polarizability'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['dipole_polarizability'])
    refined_perovskite_df[f'element_{i}_density'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['density'])
# Out:
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_specific_heat'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['specific_heat'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_evaporation_heat'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['evaporation_heat'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_dipole_polarizability'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['dipole_polarizability'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_density'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['density'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:23: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_covalent_radius'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['covalent_radius'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_fusion_heat'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['fusion_heat'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:25: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_atomic_mass'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['atomic_mass'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_specific_heat'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['specific_heat'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:27: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_evaporation_heat'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['evaporation_heat'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:28: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_dipole_polarizability'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['dipole_polarizability'])
# C:\Users\varap\AppData\Local\Temp\ipykernel_11816\370439505.py:29: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   refined_perovskite_df[f'element_{i}_density'] = refined_perovskite_df[f'element_{i}'].map(lambda x: element_properties[x]['density'])

# %%
refined_perovskite_df
# Out:
#       nsites     chemsys      volume   density  density_atomic  \
# 43        10  Ba-Cd-Mo-O  152.172247  6.318198       15.217225
# 44        10  Ba-Cd-O-Os  150.605592  7.423540       15.060559
# 45        10  Ba-Cd-O-Re  151.219499  7.349226       15.121950
# 71        20  Ba-Co-Mo-O  276.766068  6.306065       13.838303
# 72        20  Ba-Co-Mo-O  277.167172  6.296940       13.858359
# ...      ...         ...         ...       ...             ...
# 4806      10   Au-I-Rb-Y  443.643517  4.559802       44.364352
# 4807      10  Br-Cu-Rb-Y  332.890138  4.004624       33.289014
# 4808      10  Cl-Cu-Rb-Y  283.652711  3.138430       28.365271
# 4809      10   Cu-F-Rb-Y  179.308176  4.050474       17.930818
# 4810      10   Cu-I-Rb-Y  414.928559  4.341414       41.492856
#
#       energy_per_atom  formation_energy_per_atom  is_stable  band_gap     cbm  \
# 43          -7.002457                  -2.466738       True    2.5376  4.6264
# 44          -6.794457                  -2.220566       True    0.0000     NaN
# 45          -7.155684                  -2.459718      False    0.0000     NaN
# 71          -7.613764                  -2.460704       True    0.0000     NaN
# 72          -7.604548                  -2.451488      False    1.2740  4.2504
# ...               ...                        ...        ...       ...     ...
# 4806        -3.403616                  -1.345192      False    1.1678  2.4738
# 4807        -4.048370                  -1.859617      False    2.3405  3.4050
# 4808        -4.496769                  -2.130710      False    2.6201  4.4170
# 4809        -5.549890                  -3.146066      False    0.9338  3.3825
# 4810        -3.520014                  -1.379058      False    1.8014  3.6691
#
#       ...  element_3_evaporation_heat  element_3_dipole_polarizability  \
# 43    ...                       590.0                             87.0
# 44    ...                         NaN                              5.3
# 45    ...                         NaN                              5.3
# 71    ...                       590.0                             87.0
# 72    ...                       590.0                             87.0
# ...   ...                         ...                              ...
# 4806  ...                        75.8                            319.8
# 4807  ...                        75.8                            319.8
# 4808  ...                        75.8                            319.8
# 4809  ...                        75.8                            319.8
# 4810  ...                        75.8                            319.8
#
#       element_3_density  element_4_covalent_radius element_4_fusion_heat  \
# 43            10.200000                       63.0                   NaN
# 44             0.001308                      129.0                  31.7
# 45             0.001308                      131.0                  34.0
# 71            10.200000                       63.0                   NaN
# 72            10.200000                       63.0                   NaN
# ...                 ...                        ...                   ...
# 4806           1.530000                      163.0                  11.5
# 4807           1.530000                      163.0                  11.5
# 4808           1.530000                      163.0                  11.5
# 4809           1.530000                      163.0                  11.5
# 4810           1.530000                      163.0                  11.5
#
#      element_4_atomic_mass  element_4_specific_heat  \
# 43                15.99900                    0.918
# 44               190.23000                    0.130
# 45               186.20700                    0.137
# 71                15.99900                    0.918
# 72                15.99900                    0.918
# ...                    ...                      ...
# 4806              88.90584                    0.298
# 4807              88.90584                    0.298
# 4808              88.90584                    0.298
# 4809              88.90584                    0.298
# 4810              88.90584                    0.298
#
#       element_4_evaporation_heat  element_4_dipole_polarizability  \
# 43                           NaN                              5.3
# 44                         738.0                             57.0
# 45                         704.0                             62.0
# 71                           NaN                              5.3
# 72                           NaN                              5.3
# ...                          ...                              ...
# 4806                       367.0                            162.0
# 4807                       367.0                            162.0
# 4808                       367.0                            162.0
# 4809                       367.0                            162.0
# 4810                       367.0                            162.0
#
#       element_4_density
# 43             0.001308
# 44            22.587200
# 45            20.800000
# 71             0.001308
# 72             0.001308
# ...                 ...
# 4806           4.470000
# 4807           4.470000
# 4808           4.470000
# 4809           4.470000
# 4810           4.470000
#
# [920 rows x 127 columns]

# %%
# Later, while doing the data analysis, some columns will be dropped and some will be added
# We should save this data in csv format so that all we need not to repeat all these steps

csv_file = 'MaterialsProject_Double_Perovskite_data.csv'
refined_perovskite_df.to_csv(csv_file, index=False) # Converting the extracted data into a csv and saving it!
